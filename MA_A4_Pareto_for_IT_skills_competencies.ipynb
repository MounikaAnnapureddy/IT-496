# %% [markdown]
# <a href="https://colab.research.google.com/github/MounikaAnnapureddy/IT-496/blob/main/MA_A4_Pareto_for_IT_skills_competencies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt 
from matplotlib.ticker import PercentFormatter
df=pd.read_csv("/content/drive/MyDrive/paretochart_HW.csv")
print(df)
# Out:
#               Skill/Competencies                      Learning Category  Cost
# 0       Technology Strategy (TP)                     Project Management    24
# 1      Organization Agility (TP)                         Agile Training    16
# 2           Process Centric (BK)                            IT services    19
# 3        Industry Knowledge (MK)                      Industry Landscpe    18
# 4  Opportunities/Challenges (BK)                             Networking    23
# 5         Product Knowledge (MK)  Leadership training: on-site/off-site    25

# %%
df.index=df['Skill/Competencies']
df=df.sort_values(by='Cost',ascending=False)
print(df)
# Out:
#                                           Skill/Competencies  \
# Skill/Competencies
# Product Knowledge (MK)                Product Knowledge (MK)
# Technology Strategy (TP)            Technology Strategy (TP)
# Opportunities/Challenges (BK)  Opportunities/Challenges (BK)
# Process Centric (BK)                    Process Centric (BK)
# Industry Knowledge (MK)              Industry Knowledge (MK)
# Organization Agility (TP)          Organization Agility (TP)
#
#                                                    Learning Category  Cost
# Skill/Competencies
# Product Knowledge (MK)         Leadership training: on-site/off-site    25
# Technology Strategy (TP)                          Project Management    24
# Opportunities/Challenges (BK)                             Networking    23
# Process Centric (BK)                                     IT services    19
# Industry Knowledge (MK)                            Industry Landscpe    18
# ...

# %%
df["cumulativePercentage"]=df["Cost"].cumsum()/df["Cost"].sum()*100
df["cumulativePercentage"]=df["cumulativePercentage"].apply(lambda x: round(x,2))
print (df)
# Out:
#                                           Skill/Competencies  \
# Skill/Competencies
# Product Knowledge (MK)                Product Knowledge (MK)
# Technology Strategy (TP)            Technology Strategy (TP)
# Opportunities/Challenges (BK)  Opportunities/Challenges (BK)
# Process Centric (BK)                    Process Centric (BK)
# Industry Knowledge (MK)              Industry Knowledge (MK)
# Organization Agility (TP)          Organization Agility (TP)
#
#                                                    Learning Category  Cost  \
# Skill/Competencies
# Product Knowledge (MK)         Leadership training: on-site/off-site    25
# Technology Strategy (TP)                          Project Management    24
# Opportunities/Challenges (BK)                             Networking    23
# Process Centric (BK)                                     IT services    19
# Industry Knowledge (MK)                            Industry Landscpe    18
# ...

# %%
fig, ax = plt.subplots()
ax.bar(df.index, df["Cost"], color="C0")
ax.set_xticklabels(df['Skill/Competencies'], rotation=45)
ax2=ax.twinx()
ax2.plot(df.index, df["cumulativePercentage"], color="C1", marker="D", ms=7, label=df['cumulativePercentage'])
ax2.yaxis.set_major_formatter(PercentFormatter())
ax.tick_params(axis="y", colors="C0")
ax2.tick_params(axis="y", colors="C1")
for index, v in df.iterrows():
  label = round(v['cumulativePercentage'],1)
  plt.annotate(label, xy=(v['Skill/Competencies'],v['cumulativePercentage']))
plt.show()
